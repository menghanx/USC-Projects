# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('wordnet')
import re
import string
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\xmh91\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#! pip install bs4 # in case you don't have it installed

# Dataset: https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Kitchen_v1_00.tsv.gz

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv("amazon_reviews_us_Kitchen_v1_00.tsv.gz", sep='\t', error_bad_lines=False, warn_bad_lines=False)

# %% [markdown]
# ## Keep Reviews and Ratings

# %%
df2 = df[['star_rating', 'review_body']].dropna(subset=['review_body'])

# %% [markdown]
# # Labelling Reviews:
# ## The reviews with rating 4,5 are labelled to be 1 and 1,2 are labelled as 0. Discard the reviews with rating 3'

# %%
# Drop rating 3 rows
three_indexes = df2[ df2['star_rating'] == 3 ].index
df2.drop(three_indexes, inplace = True)

# Lebal samples according to rating
df2['label'] = 1
df2.loc[df2['star_rating'] <= 2, 'label'] = 0

#pd.value_counts(df2['label']).plot.bar()

# %% [markdown]
#  ## We select 200000 reviews randomly with 100,000 positive and 100,000 negative reviews.

# %%
# select reviews
df_pos = df2.loc[df2['label'] == 1].sample(1000000)
df_neg = df2.loc[df2['label'] == 0].sample(1000000)
# select pos and neg train and test data
train_pos, test_pos = train_test_split(df_pos, test_size=0.2)
train_neg, test_neg = train_test_split(df_neg, test_size=0.2)
# combine pos and neg data
train_data = train_pos.append(train_neg)
test_data = test_pos.append(test_neg)

# %% [markdown]
# # Data Cleaning
#
# ## Convert the all reviews into the lower case.

# %%
train_data['review_body'] = train_data['review_body'].str.lower()
test_data['review_body'] = test_data['review_body'].str.lower()
train_data.head(50)
# Out:
#          star_rating                                        review_body  label
# 3476398          5.0  bought this one to replace the exact model.  w...      1
# 2974696          5.0  i love these grips. i use it when grilling, se...      1
# 1233331          5.0  perfect for my huge ham which was why i purcha...      1
# 2756099          5.0  mesh is fine - no problems with pulp. used to ...      1
# 147917           5.0                                             great!      1
# 1077298          5.0                        bright color. typical flask      1
# 1549988          5.0  arrived just in time for the holidays. this wa...      1
# 1116929          5.0  it's a nice set, but i put my sash in the drye...      1
# 383814           5.0                worked perfect for our magic bullet      1
# 3410975          5.0  and i'm not sure that i can do this knife just...      1
# 1714893          5.0  great grinder processes as fast as the bagger ...      1
# 4218325          5.0  i get compliments on this constantly. guys in ...      1
# 718034           5.0  probably one of the best knives you can buy (a...      1
# 2068288          5.0             best idea ever...love this for the gym      1
# 379798           5.0                                         great gift      1
# 4728818          5.0  i know it seems crazy to even be reviewing a p...      1
# 173848           5.0  perfect, just what i needed, definitely recomm...      1
# 2417698          5.0  my parents had one similar to this in the mid-...      1
# 1298116          5.0  love these dishes! they are a good weight and ...      1
# 1423041          5.0  beautiful! these are just beautiful. i don't g...      1
# 2386428          5.0  these are the guys you want around you when pu...      1
# 2584002          5.0  i bought this to replace my oxo good grips liq...      1
# 1449184          5.0                                            love it      1
# 4386551          4.0  the other reviews are not wrong - the packagin...      1
# 4001971          4.0  i bought this to put my viking ss pans on.  no...      1
# 3994062          4.0  my wife loves buying quality tea from places s...      1
# 1241247          5.0                                           love it.      1
# 4047588          5.0  we purchased this for home use; it looks and w...      1
# 1715736          5.0                                          very good      1
# 436859           5.0  i love thi small coffeemaker. it serves my nee...      1
# 2699483          4.0  i don't have any issues with this coffee maker...      1
# 1648181          5.0                                   nice tea kettle.      1
# 514669           5.0  i've bought a handful of salad spinners over t...      1
# 2676458          5.0  i love this! you can be very creative with thi...      1
# 1617550          5.0                          great just what he wanted      1
# 3347539          5.0  while searching for silverware i found out abo...      1
# 1710587          5.0  worked perfectly, really easy. i just sliced o...      1
# 1135066          4.0                        works great as advertised..      1
# 2936619          5.0  i love the fact that this cutter has no moving...      1
# 2718792          5.0  the colors are amazing in person! im so happy ...      1
# 1935938          5.0      this perculator makes the best pot of coffee.      1
# 2285897          5.0                                               gift      1
# 4030527          4.0  i recently redecorated my kitchen to this patt...      1
# 814220           5.0              neogeo online collection complete box      1
# 1390951          5.0  you get exactly what is pictured. had been usi...      1
# 3901394          5.0  simple. this is the best mechanical corkscrew/...      1
# 1029969          5.0                                         excellent!      1
# 3663027          5.0  i wouldn't run my oven without it.  i've used ...      1
# 4304351          5.0  wusthof knives are incredible.  you won't real...      1
# 2675043          5.0  every job needs just the right tool. this is j...      1

# %% [markdown]
# ## remove the HTML and URLs from the reviews

# %%
def remove_html_url(s):
    # parse html
    soup = BeautifulSoup(s, "html.parser")
    
    for data in soup(['style', 'script']):
        # remove tags
        data.decompose()
    # replace url with empty string and return
    return re.sub(r"http\S+", "", ' '.join(soup.stripped_strings))

# Remove HTML markups and URL in text format
train_data['review_body'] = [ remove_html_url(review) for review in train_data['review_body'] ]
test_data['review_body'] = [ remove_html_url(review) for review in test_data['review_body'] ]

print(train_data.loc[3901394, ['review_body']].review_body)
# Out:
# simple. this is the best mechanical corkscrew/wine opener on the market. it's quick, it's easy, and it's consistent. this product made me seriously reconsider my method of removing the foil covering the cork... when that becomes the most time consuming part of opening a bottle of wine it's a victory for the corkscrew! it even takes me longer to pull it out of the drawer than to remove the cork. it took a few practice bottles (yummmmmm) to get the \\"touch\\" but after that it became as easy to open a bottle of wine as putting a hot knife through butter. it's not hard to get the \\"touch\\", just stabilize, firm constant squeeze, and steady down/up on the lever. warning*** be careful lending this to your neighbor or letting other use it even in your own home without a demonstration on the first bottle of wine... if there is only one bottle of wine what the heck are you doing letting someone else open it at your house!?!?!  seriously though this thing is amazing if you have the \\"touch\\" (aka know how to use it) but can really piss you off and lead you to try and force things and/or break it if you do not have the touch.

# %%
# To be removed
print(train_data.loc[1095000, ['review_body']].review_body)
# Out:
# bought for a second home my husband's words get rid of it very hard to fill with water leaks all over when pouring coffee every single time awful does not work as intended

# %% [markdown]
# ## remove non-alphabetical characters. -> perform contractions on the reviews.

# %%
def remove_non_alphabetical(s):
    # remove numbers
    #s = re.sub(r'\d+', '', s)
    
    # replace non-alphabetical by whitespace
    s = re.sub(r"[^a-zA-Z'’]", ' ', s)
    
    # remove punctuation and return
    #return ' '.join([word.strip(string.punctuation) for word in s.split(" ")])
    return s

train_data['review_body'] = [ remove_non_alphabetical(review) for review in train_data['review_body'] ]
test_data['review_body'] = [ remove_non_alphabetical(review) for review in test_data['review_body'] ]

# %% [markdown]
# ## Remove the extra spaces between the words. -> remove non-alphabetical characters

# %%
train_data['review_body'] = [ re.sub(r'\s+', ' ', review) for review in train_data['review_body'] ]
test_data['review_body'] = [ re.sub(r'\s+', ' ', review) for review in test_data['review_body'] ]
print(train_data.head(50))
# Out:
#          star_rating                                        review_body  label
# 3476398          5.0  bought one replace exact model wore old coffee...      1
# 2974696          5.0  love grips use grilling serving broiling etc c...      1
# 1233331          5.0  perfect huge ham purchased cleaned nicely matc...      1
# 2756099          5.0  mesh fine problems pulp used make green juice ...      1
# 147917           5.0                                             great       1
# 1077298          5.0                         bright color typical flask      1
# 1549988          5.0  arrived time holidays great purchase use twice...      1
# 1116929          5.0                 nice set put sash dryer get lines       1
# 383814           5.0                        worked perfect magic bullet      1
# 3410975          5.0  sure knife justice wonderfully primitive look ...      1
# 1714893          5.0      great grinder processes fast bagger bag label      1
# 4218325          5.0  get compliments constantly guys office actuall...      1
# 718034           5.0  probably one best knives buy chef used lot sha...      1
# 2068288          5.0                            best idea ever love gym      1
# 379798           5.0                                         great gift      1
# 4728818          5.0  know seems crazy even reviewing potholder thin...      1
# 173848           5.0  perfect needed definitely recommend work expec...      1
# 2417698          5.0  parents one similar mid friend coffee gourmet ...      1
# 1298116          5.0                     love dishes good weight color       1
# 1423041          5.0  beautiful beautiful get use largest one big re...      1
# 2386428          5.0  guys want around putting major production reci...      1
# 2584002          5.0  bought replace oxo good grips liquaseal big im...      1
# 1449184          5.0                                               love      1
# 4386551          4.0  reviews wrong packaging weak likely arrive lit...      1
# 4001971          4.0  bought put viking ss pans beefy enough handle ...      1
# 3994062          4.0  wife loves buying quality tea places teavana b...      1
# 1241247          5.0                                              love       1
# 4047588          5.0  purchased home use looks works great another d...      1
# 1715736          5.0                                               good      1
# 436859           5.0  love thi small coffeemaker serves needs well p...      1
# 2699483          4.0  issues coffee maker since drink distilled desi...      1
# 1648181          5.0                                   nice tea kettle       1
# 514669           5.0  bought handful salad spinners years string pul...      1
# 2676458          5.0  love creative item like depth large enough ima...      1
# 1617550          5.0                                       great wanted      1
# 3347539          5.0  searching silverware found decided whatever pu...      1
# 1710587          5.0  worked perfectly really easy sliced top sectio...      1
# 1135066          4.0                            works great advertised       1
# 2936619          5.0  love fact cutter moving parts break many style...      1
# 2718792          5.0  colors amazing person im happy went set piece ...      1
# 1935938          5.0                  perculator makes best pot coffee       1
# 2285897          5.0                                               gift      1
# 4030527          4.0  recently redecorated kitchen pattern spoonrest...      1
# 814220           5.0              neogeo online collection complete box      1
# 1390951          5.0  get exactly pictured using year already conven...      1
# 3901394          5.0  simple best mechanical corkscrew wine opener m...      1
# 1029969          5.0                                         excellent       1
# 3663027          5.0  would run oven without used things aluminum fo...      1
# 4304351          5.0  wusthof knives incredible realize dull current...      1
# 2675043          5.0  every job needs right tool right tool coconuts...      1

# %% [markdown]
# ## perform contractions on the reviews. ->  Remove the extra spaces between the words.

# %%
 def contractionfunction(s):

    contractions = {
        "a'ight": "alright",
        "ain't": "am not",
        "amn't": "am not",
        "arencha": "are not you",
        "aren't": "are not",
        "‘bout": "about",
        "cannot": "can not",
        "can't": "cannot",
        "cap’n": "captain",
        "cause": "because",
        "’cept": "except",
        "could've": "could have",
        "couldn't": "could not",
        "couldn't've": "could not have",
        "dammit": "damn it",
        "daren't": "dare not",
        "daresn't": "dare not",
        "dasn't": "dare not",
        "didn't": "did not",
        "doesn't": "does not",
        "don't": "do not",
        "dunno": "do not know",
        "d'ye": "did you",
        "e'en": "even",
        "e'er": "ever",
        "em": "them",
        "everybody's": "everybody is",
        "everyone's": "everyone is",
        "fo’c’sle": "forecastle",
        "’gainst": "against",
        "g'day": "good day",
        "gimme": "give me",
        "giv'n": "given",
        "gonna": "going to",
        "gon't": "go not",
        "gotta": "got to",
        "hadn't": "had not",
        "had've": "had have",
        "hasn't": "has not",
        "haven't": "have not",
        "he'd": "he would",
        "he'll": "he will",
        "helluva": "hell of a",
        "he's": "he is",
        "here's": "here is",
        "how'd": "how did",
        "howdy": "how do you do",
        "how'll": "how will",
        "how're": "how are",
        "how's": "how is",
        "i'd": "i would",
        "i'd've": "i would have",
        "i'll": "i will",
        "i'm": "i am",
        "imma": "i am about to",
        "i'm'o": "i am going to",
        "innit": "is it not",
        "ion": "i do not",
        "i've": "i have",
        "isn't": "is not",
        "it'd": "it would",
        "it'll": "it will",
        "it's": "it is",
        "iunno": "i do not know",
        "kinda": "kind of",
        "let's": "let us",
        "ma'am": "madam",
        "mayn't": "may not",
        "may've": "may have",
        "methinks": "i think",
        "mightn't": "might not",
        "might've": "might have",
        "mustn't": "must not",
        "mustn't've": "must not have",
        "must've": "must have",
        "‘neath": "beneath",
        "needn't": "need not",
        "nal": "and all",
        "ne'er": "never",
        "o'clock": "of the clock",
        "o'er": "over",
        "ol'": "old",
        "oughtn't": "ought not",
        "‘round": "around",
        "s": "is",
        "shalln't": "shall not",
        "shan't": "shall not",
        "she'd": "she would",
        "she'll": "she will",
        "she's": "she is",
        "should've": "should have",
        "shouldn't": "should not",
        "shouldn't've": "should not have",
        "somebody's": "somebody is",
        "someone's": "someone is",
        "something's": "something is",
        "so're": "so are",
        "so’s": "so has",
        "so’ve": "so have",
        "that'll": "that will",
        "that're": "that are",
        "that's": "that is",
        "that'd": "that would",
        "there'd": "there would",
        "there'll": "there will",
        "there're": "there are",
        "there's": "there is",
        "these're": "these are",
        "these've": "these have",
        "they'd": "they would",
        "they'll": "they will",
        "they're": "they are",
        "they've": "they have",
        "this's": "this is",
        "those're": "those are",
        "those've": "those have",
        "thout": "without",
        "’til": "until",
        "tis": "it is",
        "to've": "to have",
        "twas": "it was",
        "tween": "between",
        "twere": "it were",
        "wanna": "want to",
        "wasn't": "was not",
        "we'd": "we would",
        "we'd've": "we would have",
        "we'll": "we will",
        "we're": "we are",
        "we've": "we have",
        "weren't": "were not",
        "whatcha": "what are you",
        "what'd": "what did",
        "what'll": "what will",
        "what're": "what are/what were",
        "what's": "what is",
        "what've": "what have",
        "when's": "when is",
        "where'd": "where did",
        "where'll": "where will",
        "where're": "where are",
        "where's": "where is",
        "where've": "where have",
        "which'd": "which had",
        "which'll": "which will",
        "which're": "which are",
        "which's": "which is",
        "which've": "which have",
        "who'd": "who would",
        "who'd've": "who would have",
        "who'll": "who will",
        "who're": "who are",
        "who's": "who is",
        "who've": "who have",
        "why'd": "why did",
        "why're": "why are",
        "why's": "why is",
        "willn't": "will not",
        "won't": "will not",
        "wonnot": "will not",
        "would've": "would have",
        "wouldn't": "would not",
        "wouldn't've": "would not have",
        "y'all": "you all",
        "y'all'd've": "you all would have",
        "y'all'd'n't've": "you all would not have",
        "y'all're": "you all are",
        "y'all'ren't": "you all are not",
        "y'at": "you at",
        "yes’m": "yes madam",
        "yessir": "yes sir",
        "you'd": "you would",
        "you'll": "you will",
        "you're": "you are",
        "you've": "you have",
        "'s": ""
    }
    
    
    for word in s.split(" "):
        if word in contractions:
            s = s.replace(word, contractions[word])
    return s

train_data['review_body'] = [ contractionfunction(review) for review in train_data['review_body'] ]
test_data['review_body'] = [ contractionfunction(review) for review in test_data['review_body'] ]

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## remove the stop words

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def remove_stopwords(s):
    # only keep words not in stopwords set
    filtered_words = [word for word in s.split(" ") if word not in stop_words]
    return " ".join(filtered_words)

train_data['review_body'] = [ remove_stopwords(review) for review in train_data['review_body'] ]
test_data['review_body'] = [ remove_stopwords(review) for review in test_data['review_body'] ]

# %% [markdown]
# ## perform lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN) 



print(lemmatizer.lemmatize(word, get_wordnet_pos(word)))
# Out:
# husband's

# %% [markdown]
# # TF-IDF Feature Extraction

# %% [markdown]
# # Perceptron

# %% [markdown]
# # SVM

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # Naive Bayes
