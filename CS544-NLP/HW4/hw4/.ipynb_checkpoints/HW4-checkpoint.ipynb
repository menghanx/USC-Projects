# %%
import pandas as pd
import numpy as np
import nltk, re, json

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.datasets as transforms

from sklearn.model_selection import train_test_split

# %%
def readFile(file):
    f = open(file)
    lines = f.readlines()
    words = []
    for line in lines:
        if line.strip():
            words.append(line.strip().split(' '))
    return words

# %%
# store train sentences 
train_file = 'data/train'
dev_file = 'data/dev'
test_file = 'data/test'

# %%
train_lines = readFile(train_file)
df = pd.DataFrame(train_lines, columns = ["s_idx", "word", "tag"])

# %%
# Randomly select some rare words to be <unk> words
unique_words = df["word"].value_counts().reset_index()
unique_words.columns = ["word", "freq"]
threshold = 1
vocab_words = unique_words[ unique_words['freq'] > threshold ]
rare_words = unique_words[ unique_words['freq'] == threshold ]
print("vocab words:", vocab_words.shape[0])
print("rare words:", rare_words.shape[0])
# Out:
# vocab words: 11983
# rare words: 11641

# %%
# Randomly select 3000 words from rare words to set as unknown words
unk_count = 3000
unk_rares = rare_words.sample(unk_count)

# Use this list to replace train words to <unk>
unk_set = set(unk_rares["word"].unique().tolist())

# drop selected rare words from rare words
rest_rares = rare_words.drop(unk_rares.index)

# build new vocab = freq_words + rest_rare_words + <unk>
vocab = vocab_words.append(rest_rares, ignore_index=True)
unk_row = pd.DataFrame([["<unk>", 3000]], columns = ["word", "freq"])
vocab = vocab.append(unk_row, ignore_index=True)

# main vocab list, to generate embedding
vocab_set = set(vocab['word'].unique().tolist())

# %%
input_dim = 100
lstm_layer = 1
hidden_dim = 256
lstm_dropout = 0.33
linear_out_dim = 128

# all the tags
tags = set(df["tag"].unique())
tag_to_idx = {tag:i for i, tag in enumerate(tags)}
num_classes = len(df["tag"].unique())

# all the vocab
word_to_idx = {word:i for i, word in enumerate(vocab_set)}
# embeds = nn.Embedding(len(vocab), input_dim)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def readSentences(file):
    f = open(file)
    lines = f.readlines()
    sentences = []
    sentence = []
    for line in lines:
        if not line.strip():
            sentences.append(sentence.copy())
            sentence.clear()
        else:
            sentence.append(line.strip().split(' '))
    # append the last sentence
    sentences.append(sentence.copy())
    return sentences

# %%
# Group sentences together
train_file = 'data/train'
dev_file = 'data/dev'
test_file = 'data/test'

# word = [idx, word, tag]
train_sentences = readSentences(train_file)
dev_sentences = readSentences(dev_file)
# word = [idx, word]
test_sentences = readSentences(test_file)

# %%
print(len(train_sentences), len(dev_sentences), len(test_sentences))
# Out:
# 14987 3466 3684

# %%
dummy_file ='data/dummy'
dummy_sentences = readSentences(dummy_file)
dummy_sentences
# Out:
# [[['1', 'Weaver', 'B-PER'],
#   ['2', 'shot', 'O'],
#   ['3', 'to', 'O'],
#   ['4', 'prominence', 'O'],
#   ['5', 'in', 'O'],
#   ['6', '1994', 'O'],
#   ['7', 'when', 'O'],
#   ['8', 'he', 'O'],
#   ['9', 'won', 'O'],
#   ['10', 'the', 'O'],
#   ['11', 'English', 'B-MISC'],
#   ['12', '2,000', 'B-MISC'],
#   ['13', 'Guineas', 'I-MISC'],
#   ['14', 'on', 'O'],
#   ['15', 'Mister', 'B-LOC'],
#   ['16', 'Baileys', 'I-LOC'],
#   ['17', 'in', 'O'],
#   ['18', 'his', 'O'],
#   ['19', 'first', 'O'],
#   ['20', 'ride', 'O'],
#   ['21', 'in', 'O'],
#   ['22', 'a', 'O'],
#   ['23', 'classic', 'O'],
#   ['24', '.', 'O']],
#  [['1', 'Results', 'O'],
#   ['2', 'of', 'O'],
#   ['3', 'English', 'B-MISC'],
#   ['4', 'league', 'O'],
#   ['5', 'matches', 'O']]]

# %%
def makeData(sentences):
    inputs = []
    targets = []
    for sentence in sentences:
        word_idx = []
        target = []
        for word in sentence:
            if word[1] in vocab_set:
                word_idx.append(word_to_idx[word[1]])
            else:
                word_idx.append(word_to_idx['<unk>'])            
            target.append(tag_to_idx[word[2]])
        inputs.append(word_idx)
        targets.append(target)
    return inputs, targets

# %%
word_to_idx['<unk>']
# Out:
# 18762

# %%
makeData(dummy_sentences)
# Out:
# ([[13244,
#    6244,
#    10461,
#    16573,
#    11161,
#    4466,
#    7331,
#    7126,
#    2098,
#    13859,
#    19747,
#    11692,
#    2973,
#    13325,
#    11308,
#    18762,
#    11161,
#    14128,
#    9291,
#    17302,
#    11161,
#    9525,
#    18762,
#    10983],
#   [4341, 17001, 19747, 19233, 700]],
#  [[1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 0, 0, 3, 4, 6, 7, 4, 4, 4, 4, 4, 4, 4, 4],
#   [4, 4, 0, 4, 4]])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22888/2553580700.py in <module>
# ----> 1 torch.LongTensor(input_batch)
#
# ValueError: expected sequence of length 24 at dim 1 (got 5)

# %%
def getEmbedding(word):
    index = word_to_idx[word]
    lookup_tensor = torch.tensor(index, dtype=torch.long)
    return embeds(lookup_tensor)

# %%
unk_set
# Out:
# {'Baileys',
#  'perilous',
#  '13.33',
#  'teacher',
#  'servicing',
#  '1203',
#  '2:44.22',
#  'KABUL',
#  'comi',
#  '23-27',
#  'stretching',
#  'harrowing',
#  'Gjon',
#  'Hess',
#  '12.124',
#  'Likkason',
#  '1:45.62',
#  'Man-of-the-Match',
#  'dwell',
#  'startups',
#  '112.8',
#  'mobilised',
#  'Fannie',
#  'Warren',
#  'BOOK',
#  'Koeln',
#  'untie',
#  'sadmasochistic',
#  'Nikiforov',
#  '90.18',
#  '7.84',
#  'implying',
#  'portfolios',
#  'compromised',
#  'fortunate',
#  '12.2',
#  'Massira',
#  'ostracism',
#  'Angelica',
#  'RSR',
#  'Kryvy',
#  'comprises',
#  '469',
#  'Pentagon',
#  'Bernardo',
#  'long-delayed',
#  'half-volley',
#  '8-10',
#  '21.JAN.99',
#  '1,294.5',
#  '65-8703092',
#  'IN-NAZZJON',
#  'Gorgona',
#  '5,700',
#  'fifth-placed',
#  'Boopathy',
#  '1,130',
#  'Mendy',
#  '27-4',
#  'kingdoms',
#  '62.50',
#  'well-wishers',
#  'Conc',
#  '2030',
#  'Dnipropetrovsk',
#  '146.2',
#  'hat-tricks',
#  'Syrian-Lebanese',
#  '.571',
#  'Ralf',
#  '45.455',
#  'firefighters',
#  'scoreboard',
#  'square-leg',
#  'vulnerable',
#  'DNEVNI',
#  'Supermarkets',
#  '212-859-1736',
#  'Eleonora',
#  'Yap',
#  'MCC',
#  '44.78',
#  'halfback',
#  'suppress',
#  'Kanie',
#  '5.85',
#  'Barkho',
#  'awfully',
#  '39.2',
#  '4,464',
#  '3:33.64',
#  '1:04.896',
#  'FR',
#  'dominance',
#  'Robin',
#  'Kojima',
#  'withdrawing',
#  'indoor',
#  'gaps',
#  'swiss',
#  '2010',
#  'Chiapas',
#  'Kiptanui',
#  'Half-year',
#  'immi',
#  '1966-76',
#  'Plant',
#  'louder',
#  'participated',
#  '20-metre',
#  '165,150',
#  'Confederacy',
#  'Baggio',
#  '251/04',
#  'Code',
#  '291,088',
#  'joint-venture',
#  'persisted',
#  'Orthodox',
#  'outcast',
#  'Ion',
#  'GIVES',
#  'hottest',
#  'diocese',
#  'Jan-July',
#  'Economists',
#  '11,525',
#  'laughed',
#  'WEI',
#  'Vandenbroucke',
#  'pelted',
#  '13,000',
#  'troubles',
#  '1:51.006',
#  'Georgy',
#  'nerve',
#  '39,584',
#  'JOUR',
#  'Richmond-based',
#  'derision',
#  'anti-Rangoon',
#  'KNUP',
#  'chardonnay',
#  'promotional',
#  '143.7',
#  'generalisation',
#  '334',
#  'al-Ingaz',
#  'bowlers',
#  'Ambrose',
#  'ham',
#  'Dunedin',
#  'debt-service',
#  'trains',
#  'Charlier',
#  'supervision',
#  '266.37',
#  'Djiwandono',
#  'Probably',
#  'indexation',
#  'Mohammedia',
#  '105,000',
#  'Equipment',
#  'Adriana',
#  'adversories',
#  'genetic',
#  'Jian',
#  'PAPENDRECHT',
#  'end-May',
#  '96.00',
#  'Mitsotakis',
#  'complicated',
#  'shifts',
#  'Rojas',
#  'Dreekman',
#  'Edhem',
#  'Six-month',
#  'maul',
#  'completes',
#  'Rouser',
#  'Oerlikon',
#  '3:33.00',
#  'book-building',
#  'sequels',
#  'Anytime',
#  'dispensation',
#  '52-week',
#  '2-19',
#  'Etienne',
#  'unfocused',
#  'FINNISH',
#  'DODGE',
#  '14-0-71-0',
#  'Falkir',
#  'Iberia',
#  '15.5',
#  'Mugica',
#  'upwards',
#  'union-England',
#  'Cvetko',
#  'hijacker',
#  'PERTH',
#  'topping',
#  '123.89',
#  'pro-life',
#  'soar',
#  'confessing',
#  '0300',
#  'Phylis',
#  'DLJ',
#  '11,346,000',
#  'flees',
#  'robberies',
#  '5-67',
#  'Vinko',
#  'Bulatka',
#  '23.25',
#  '199,900',
#  'newsletter',
#  'desert',
#  'Posner',
#  'twin',
#  'Zarcas',
#  'head-butting',
#  'divergent',
#  '18,278',
#  'passion',
#  'Arrivals',
#  'GREEN',
#  'Republican-controlled',
#  'unusual',
#  'MULDER',
#  'Lezion',
#  'shrine',
#  '.453',
#  'AVIA',
#  'Ancelotti',
#  'Indah',
#  'Swiss-based',
#  'retaining',
#  'Specialists',
#  'Sot',
#  'Beersheva',
#  'fervant',
#  '.549',
#  'Soviet-era',
#  '7.77',
#  'Townsend',
#  '1:05.731',
#  '22,666.80',
#  'Bottomley',
#  'Arnaut',
#  'Steinberg',
#  '20.036',
#  'unveiling',
#  'Dehaan',
#  'Proposition',
#  'conventional',
#  'setback',
#  'cease-fire',
#  'Fixed',
#  'Esposito',
#  'predicated',
#  '91.05',
#  '1992/93',
#  '8167',
#  '.349',
#  'Polverino',
#  'footing',
#  'Mich',
#  'Pells',
#  '115.32',
#  'Sgt',
#  '97.38',
#  'relived',
#  '2.37',
#  'Lengths',
#  'Guofang',
#  'looting',
#  'occured',
#  'Gehrig',
#  're-elect',
#  'ideological',
#  'accurate',
#  'Lixion',
#  'Closing',
#  'unrepentant',
#  '24,800',
#  'lens',
#  'rain-soaked',
#  'impede',
#  'sprinted',
#  'Platinum',
#  '34-48',
#  'conf',
#  'three-match',
#  'Umbria',
#  'limping',
#  'revolvers',
#  'prohibitively',
#  'detentions',
#  'quietly',
#  '75,632',
#  '2:30.67',
#  'RABN.CN',
#  'abdominal',
#  '13.64',
#  'Remarkably',
#  'Nikki',
#  '35-23',
#  'pro-woman',
#  'Jungle',
#  'Ausmus',
#  'FISCAL',
#  'Hoffmann',
#  'paparazzi',
#  'comparable',
#  'teetotaller',
#  'solemn',
#  'Surin',
#  'Indre',
#  'Stephnopoulos',
#  '3:03',
#  'guests',
#  '83,008',
#  'protecting',
#  'checkpoints',
#  '20.48',
#  'Peer',
#  '3.10',
#  'Thily',
#  'Variable',
#  '603',
#  'dig',
#  'nb-7',
#  'Wachtel',
#  'valuation',
#  'Zieger',
#  'Gorleben',
#  'talked',
#  'Jui',
#  'deadpan',
#  'repo',
#  '2-0-18-0',
#  '6-20',
#  'EMBASSY',
#  'centre-right',
#  '14.3-4-45-1',
#  'front-page',
#  'Parkway',
#  'machinegun',
#  'senators',
#  'rental',
#  '1626',
#  '2.10',
#  'problematic',
#  '11,594.99',
#  'matured',
#  'dispatching',
#  'bulldozer',
#  '385-1-4557075',
#  'glow',
#  '53.706',
#  'stones',
#  'Rory',
#  'AFL',
#  'Spadea',
#  'Feagin',
#  '40-34',
#  'upgrading',
#  'Alhadji',
#  'guides',
#  'Hubert',
#  'renegotiation',
#  'listing',
#  'repositioning',
#  '1:56.417',
#  'fire-related',
#  '5-for-5',
#  'escalating',
#  'Quist',
#  '50.51',
#  '7-0-28-1',
#  'ABN',
#  'Simeonov',
#  'certificate',
#  'curve',
#  'emigrated',
#  'Mordechai',
#  'Houghton',
#  '+4.7',
#  'GLAD',
#  'square-jawed',
#  'sprained',
#  'LARNACA',
#  'suspending',
#  'coverable',
#  'strong-dollar',
#  '75,000',
#  'Mano',
#  'NATION',
#  'Contracts',
#  'Kazimierz',
#  'publisher',
#  'Regrettably',
#  'Herald',
#  'mercenaries',
#  'syndicated',
#  'Garret',
#  'Meknes',
#  '1yr',
#  'beforehand',
#  'sworn',
#  'Fiedler',
#  'fifth-',
#  'EMTN',
#  '10,880,000',
#  'towering',
#  'grueling',
#  '3:33.94',
#  'COSTA',
#  'Sud-PTT',
#  'COMMUNITY',
#  'enthusiastic',
#  'INDIANS',
#  'knocking',
#  '5,032.94',
#  'Petrobulk',
#  'crusade',
#  'Rodimov',
#  '8/30',
#  '6-0-29-1',
#  'Reid',
#  '5.55',
#  'Crawford',
#  'Khum',
#  'Sabotzik',
#  'permanently',
#  'dump',
#  'ENHANCEMENTS',
#  'assuming',
#  'procured',
#  'BSE-infected',
#  'stering',
#  'empower',
#  'Girard-Leno',
#  'Material',
#  'day-to-day',
#  'simultaneous',
#  'Cie',
#  '23.0yr',
#  'sooner',
#  'breach',
#  '10700',
#  '3,800-3,825',
#  'Kandir',
#  'BOTHAM',
#  'Nationalists',
#  'HOPES',
#  'TRADE',
#  'Roussel',
#  'talent-laden',
#  'sex-and-murder',
#  'Gowda',
#  'Billings',
#  '166-1',
#  '291',
#  '233,713',
#  'Square',
#  'apparel',
#  'Attorney-General',
#  'Willison',
#  'rob',
#  'reform-oriented',
#  'LUSAKA',
#  'Janis',
#  '48.2',
#  'KIGALI',
#  '77th',
#  'lesser',
#  '2,500-seat',
#  '1.3',
#  'TRUTH',
#  'tom',
#  'Votava',
#  'Gains',
#  'SuperCup',
#  'Jaffna',
#  '2847',
#  'clouds',
#  'detect',
#  'thumbnail',
#  '66.6-68.4',
#  'sidings',
#  'KHARTOUM',
#  '290M',
#  'incapacity',
#  '27:18.84',
#  '6320',
#  'cruising',
#  'BankWatch',
#  'touched',
#  'Morceli',
#  'Wednesay',
#  'narrowly',
#  'deliberately',
#  'protestor',
#  '1.4788',
#  '07.00',
#  'Wieczorek',
#  '0.33',
#  'Unidentified',
#  'gutted',
#  'Florian',
#  'drunkards',
#  'OH',
#  'Prosecutor-General',
#  'Ansgar',
#  'Brass',
#  '5-15',
#  '84.20',
#  'Donizetti',
#  'inspector',
#  'expert',
#  'rule-making',
#  '18,500',
#  '44,525',
#  'Argyle',
#  'HUF',
#  'debilitating',
#  'diver',
#  '142-4',
#  'BALANCE-Water',
#  '5.2420',
#  'Undersecretary-General',
#  'enthusiast',
#  '8.07',
#  'stem',
#  'Fringer',
#  'standby',
#  'Ntawulikura',
#  'Beautiful',
#  '6,150',
#  'Bergmann',
#  'floods',
#  'knife-wielding',
#  'doldrum',
#  'consciences',
#  'Matin',
#  '1:52.318',
#  '0.34',
#  'Moosa',
#  'JONK',
#  '325-350',
#  'Accountant',
#  '0:06',
#  'Equivalents',
#  'underpriviledged',
#  'bearded',
#  'co-operative',
#  'intentionally',
#  'Stinnes',
#  'post-season',
#  '1998D',
#  'Blank',
#  'quantify',
#  'ablaze',
#  '0515',
#  '14,494',
#  'jam-packed',
#  'year-olds',
#  'Estimated',
#  'Kotzmann',
#  'messed',
#  'ASARCO',
#  'participant',
#  'Tunceli',
#  'waves',
#  'Cholera',
#  'Garrett',
#  '34684',
#  'HIGHS',
#  '22,040,000',
#  'storms',
#  '88-year-old',
#  'Miners',
#  'Individuals',
#  '8:15.69',
#  'Chaloner',
#  'reappointment',
#  'Annette',
#  'acrobatic',
#  '61-year-old',
#  'Willis',
#  'Hina',
#  '918,288',
#  'BOLD',
#  'omission',
#  'Kennedys',
#  'Auchan',
#  'translators',
#  'Things',
#  '6-242',
#  'momentous',
#  'mingle',
#  'color',
#  'Royce',
#  'Vowinkel',
#  'operas',
#  'Administrator',
#  'depositions',
#  '806',
#  'dared',
#  'blasted',
#  'Eurotunnel',
#  'VERN',
#  'Rysich',
#  'bump',
#  'Montenegrin',
#  'lie',
#  'scribble',
#  'assisted',
#  'restraint',
#  '10,756',
#  'inhabitants',
#  'armfuls',
#  'Sisters',
#  'Responsibility',
#  '.443',
#  'Khotin',
#  'Checker',
#  'interruption',
#  'delta',
#  'Cam',
#  'Jewellers',
#  'Seedorf',
#  'Wembley',
#  'expulsions',
#  'transplanting',
#  'insert',
#  'Course',
#  'Dheeraj',
#  'Meads',
#  'Agent',
#  'EOE',
#  'Mangala',
#  'looming',
#  'Polster',
#  '115.62',
#  'Meluawati',
#  '275',
#  'entrances',
#  'GUILDERS',
#  'calculated',
#  'satisfy',
#  'equestrian',
#  '7715',
#  'Defiant',
#  'cigarette',
#  'Leftist',
#  'proceeds',
#  'Auchard',
#  'Through',
#  '5,350',
#  'Petrosan',
#  'honed',
#  'limp',
#  'STREAK',
#  'curse',
#  'Hawaii',
#  'undercut',
#  '446',
#  'SOYBEAN',
#  'multiply.q',
#  '2-98',
#  '727',
#  'semblance',
#  'Gyor',
#  'protege',
#  'FOCUS',
#  'levies',
#  'U',
#  '+225',
#  '8.17',
#  'Vegas',
#  '28.29.42',
#  'Bovary',
#  '15.687',
#  '16.75',
#  'mositure',
#  'refurbished',
#  'suction',
#  'fellow-American',
#  'prey',
#  '386.95',
#  '8.45',
#  '++359-2',
#  'Inter-Entity',
#  'tribe',
#  'intolerance',
#  'Absolute',
#  'Ilian',
#  '18-7/8',
#  '5.208',
#  'OPT',
#  'overcapacity',
#  'Electronics',
#  'Dynamics',
#  '36-46',
#  '1:55.333',
#  'RELATIONS',
#  'demos',
#  '330-member',
#  'opposite',
#  'financers',
#  'grill',
#  'Rupam',
#  'Jockey',
#  'Eleven',
#  'PPI',
#  'paratroop',
#  'evaluated',
#  'Endrio',
#  '9-2-26-1',
#  'CART',
#  'Lees',
#  'cms',
#  'YMCA',
#  'bottle-throwing',
#  'THUNDERSTORMS',
#  'Nacional',
#  'Kensit',
#  'Paula',
#  'distract',
#  'marvelling',
#  'manhandling',
#  'right-foot',
#  '1913',
#  'mid-Norway',
#  'pomfret-rich',
#  'Opinion',
#  'Ndiaye',
#  'PAYMENTS',
#  'lifeless',
#  'Monthly',
#  '63,913',
#  'Tap',
#  'NINTH',
#  'Hishem',
#  'Sixty',
#  'spectacular',
#  'ruler',
#  '112th-ranked',
#  '1870',
#  'Rafiqul',
#  '31.0',
#  'Help-wanted',
#  'Kolumbina',
#  'Opel',
#  'Based',
#  '3120264',
#  'la',
#  'Attempts',
#  'Stocher',
#  '10.30',
#  'Eiden',
#  'Unseeded',
#  'Constructors',
#  '1,143',
#  '3300',
#  'hospitals',
#  'LAS',
#  '3:54.87',
#  '2.56',
#  'detainees',
#  'four-month',
#  'sensational',
#  '285,000',
#  'Cap',
#  'hunter',
#  'vision',
#  'reassure',
#  'Canadians',
#  '02.SEP.96-21.NOV.97',
#  'Thoren',
#  '7.35',
#  '3.72',
#  'Enraged',
#  'misery',
#  'simulated',
#  'truly',
#  '20.17',
#  '29th-ranked',
#  'Tando',
#  'Daniele',
#  'assemby',
#  'IAE-3',
#  'buoyed',
#  'PO',
#  '80-seat',
#  '58.92',
#  'secretariat',
#  '6-7(3-7',
#  'outmaneuvering',
#  'Nuclear',
#  'Haugland',
#  '10-1-54-0',
#  'Dopita',
#  'defenestration',
#  '0172',
#  '251/01',
#  'spoken',
#  'CLINCH',
#  'Merrion',
#  'FOUR-YEAR',
#  'Activists',
#  'RAMESWARAM',
#  'extension',
#  'Shamay',
#  'Avg',
#  '353078',
#  'belongings',
#  'galloped',
#  'concepts',
#  '9-mth',
#  'freeing',
#  'holy',
#  'spur',
#  'nevus',
#  'sawn-off',
#  'hindered',
#  'juvenile',
#  '960,000',
#  '3-4',
#  'Abdullah',
#  'III.ker.TVE',
#  'Wafa',
#  'Anxieties',
#  'defused',
#  '2-mth',
#  'deducted',
#  '3,300',
#  '375.00',
#  'EUROSWISS',
#  'Pena',
#  'retook',
#  'cutback',
#  'Footwork',
#  'Hurley',
#  'Inger',
#  'fliers',
#  'ejected',
#  'condos',
#  '29-6-64-1',
#  'references',
#  'Kidnappers',
#  'Seventy',
#  'safeguarded',
#  'tricks',
#  'Jannie',
#  '1-129',
#  'Soviet-style',
#  '1345',
#  '1:54.095',
#  'uniting',
#  'downside',
#  'Lapke',
#  'Gale',
#  '10.17',
#  'four-set',
#  'barns',
#  'routes',
#  '1:02.795',
#  'TAKES',
#  'Soprun',
#  'Micromation',
#  'grace',
#  'Adolfo',
#  'tabs',
#  '6-440',
#  'Liaoning',
#  'flawed',
#  'Grace',
#  'kneeing',
#  '941-434319',
#  'chart',
#  'Christina',
#  'Olascoaga',
#  'Construction',
#  'soy',
#  'exemption',
#  '9-0',
#  'Financing',
#  'Ruano-Pascual',
#  'infect',
#  'SDV',
#  'recommend',
#  '1,650',
#  'Cesare',
#  '2:43.44',
#  'backyard',
#  'Unified',
#  'McManaman',
#  'fees',
#  'Alina',
#  'dislodge',
#  'improving',
#  'jokes',
#  'jeeps',
#  'Venezolana',
#  'shrinks',
#  'Subandoro',
#  '60M',
#  '45.00',
#  'skills-based',
#  'downward',
#  'Ashia',
#  'Money',
#  'Artyom',
#  'confrontation',
#  'Erzincan',
#  '1.84',
#  'PHNOM',
#  'disperse',
#  'Schuman',
#  'Weidman',
#  '486.5',
#  '+7.3;-3.6',
#  'stern',
#  'technology-based',
#  'MainStay',
#  'Aid',
#  'Murphy',
#  'pubished',
#  'Motkova',
#  'newcomers',
#  '12,855.7',
#  'soup',
#  '11th-seeded',
#  '31,139',
#  'Yemeni',
#  '18-15',
#  'short-dated',
#  'Dahlan',
#  'leaked',
#  'FOWLER',
#  '6-0-23-0',
#  'estates',
#  '3,905.7',
#  'emigrates',
#  '0.0817',
#  'Montenegro',
#  'Kerry',
#  'Comfort',
#  'consumed',
#  'ENTRY',
#  'LAUDERDALE',
#  'finalising',
#  'chained',
#  'Seasongood',
#  '+1.7;+22.0',
#  'Kidikas',
#  'cereals',
#  'Saying',
#  'substantially',
#  'formulated',
#  '524',
#  'Dimas',
#  '8-0',
#  'vice-captain',
#  'relaxed',
#  '54,703.0',
#  'Gartner',
#  'acceptances',
#  'Daryll',
#  'Emese',
#  'disquiet',
#  'nighttime',
#  'deeply',
#  '0.41',
#  'cancelling',
#  '1906',
#  'Northsea',
#  'shield',
#  'oriented',
#  'fast-growing',
#  'Carrefour',
#  'Lands',
#  'fifth-stage',
#  'starker',
#  'right-hand',
#  'oilseed',
#  'shrs',
#  'schoolchildren',
#  '12-7',
#  '3359.200',
#  'voice',
#  'Barrier',
#  'Jumbish-i-Milli',
#  '8.03',
#  ...}

# %%
tests = sentences[:5]
input_batch, target_batch = makeData(tests)
input_batch
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7460/3798200530.py in <module>
#       1 tests = sentences[:5]
# ----> 2 input_batch, target_batch = makeData(tests)
#       3 input_batch
#
# ~\AppData\Local\Temp/ipykernel_7460/2627561788.py in makeData(sentences)
#       3     targets = []
#       4     for sentence in sentences:
# ----> 5         inputs.append([ word_to_idx[word[1]] for word in sentence ])
#       6         targets.append([ tag_to_idx[word[2]] for word in sentence ])
#       7     return inputs, targets
#
# ~\AppData\Local\Temp/ipykernel_7460/2627561788.py in <listcomp>(.0)
#       3     targets = []
#       4     for sentence in sentences:
# ----> 5         inputs.append([ word_to_idx[word[1]] for word in sentence ])
#       6         targets.append([ tag_to_idx[word[2]] for word in sentence ])
#       7     return inputs, targets
#
# KeyError: 'LEICESTERSHIRE'

# %%
# (batch, seq, feature)
rnn = nn.LSTM(
    input_size=input_dim, 
    hidden_size=hidden_dim,
    num_layers=1,
    batch_first=True,
    bidirectional=True,
    dropout=lstm_dropout)
# Out:
# C:\Users\xmh91\.conda\envs\py39-CS544\lib\site-packages\torch\nn\modules\rnn.py:62: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.33 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
